# %%
soru1=int(input("Evde kaç kişi yaşıyor?  "))
soru2=int(input("Yıllık kaç kwH elektrik kullanıyorsunuz?  "))
c2=(soru2*0.03366)
print("Elektrik kaynaklı karbon ayak iziniz",c2,"kg CO2")
soru3=int(input("Yıllık kaç m3 doğalgaz kullanıyorsunuz?  "))
c3=(soru3*2.1857)
print("Doğalgaz kaynaklı karbon ayak iziniz",c3,"kg CO2")
soru4=str(input("Odun kullanıyor musunuz? (evet/hayır)  "))
if soru4 == "evet":
  soru5 = int(input("Yıllık kaç kg odun kullanıyorsunuz?  "))
else :
  soru5=0
c5=(soru5*0.0014375)
soru6=str(input("Kömür kullanıyor musunuz? (evet/hayır)  "))
if soru6 == "evet":
  soru7=int(input("Yıllık kaç m3/ton kömür kullanıyorsunuz?  "))
else :
  soru7=0
c7=(soru7*2.93)
print("Yakacak kaynaklı karbon ayak iziniz",c5+c7,"kg CO2.")
a1=input("Araba kullanıyor musunuz?(evet/hayır)  ")
if a1=="evet" :
  a2=input("Arabanız hangi yakıtla çalışmaktadır? (benzin/dizel/lpg)  ")
  if a2=="benzin" :
    a=2.24
  if a2=="dizel" :
    a=2.6
  if a2=="lpg" :
    a=1.68
  c=int(input("Yılda kaç litre yakıt kullanıyorsunuz?  "))
  c8=a*c
t1=input("Toplu taşıma kullanıyor musunuz? (evet/hayır)  ")
if t1=="evet" :
 t2=int(input("Yılda kaç km yol kat ediyorsunuz?  "))
 k=6.675
 c9=t2*k
u1=int(input("Yılda kaç uçak yolcuğu yapıyorsunuz? (yapmıyorsanız 0 yazılabir)  "))
u2=int(input("Yaptığınız yolculuk kaç saat sürüyor? (tek yön)  "))
c10=u1*u2*51.460
print("Ulaşım ve seyahat kaynaklı karbon ayak iziniz",c8+c9+c10,"kg CO2.")
y1=int(input("yılda kaç kg kırmızı et tüketiyorsunuz?  "))
y2=int(input("yılda kaç kg beyaz et tüketiyorsunuz?  "))
y3=int(input("yılda kaç kg sebze tüketiyorsunuz?  "))
y4=int(input("yılda kaç kg meyve tüketiyorsunuz?  "))
y5=int(input("yılda kaç kg bakliyat tüketiyorsunuz?  "))
y6=int(input("yılda kaç kg süt ve süt ürünleri tüketiyorsunuz?  "))
y7=int(input("yılda kaç kg kuruyemiş tüketiyorsunuz?  "))
c11=(y1*33.1+y2*7.95+y3*1.92+y4+y5*1.9+y6*5.8+y7*2.8)
k1=int(input("Pamuklu, Keten, Deri vb. Organik Materyal Temelli kaç adet kıyafet satın aldınız?  "))
k2=int(input("Polyester vb. Yapay Malzemeli  kaç adet kıyafet satın aldınız?  "))
c12=k1*6.5+k2*5
print("Yaşam tarzı kaynaklı karbon ayak iziniz",c12+c11,"kg CO2.")
soru9=int(input("Yıllık kaç kg plastik atık atıyorsunuz?  "))
c13=(soru9*8.28)
soru10=int(input("Yıllık kaç kg cam  atıyorsunuz?  "))
c14=(soru10*1.2)
print("Atık kaynaklı karbon ayak iziniz",c13+c14,"kg CO2.")
import matplotlib.pyplot as plt
import numpy as np
a= np.array([c2,c3,c5+c7,c8+c9+c10,c11+c12,c13+c14])
l=["Elektrik kaynaklı karbon ayak izi","Doğalgaz kaynaklı karbon ayak izi","Yakacak kaynaklı karbon ayak izi","Ulaşım ve seyahat kaynaklı karbon ayak izi","Yaşam tarzı kaynaklı karbon ayak izi","Atık kaynaklı karbon ayak izi"]
plt.pie(a,labels=l,autopct='%1.1f%%')
print("Kişi başı karbon ayak izi",(c2+c3+c5+c7+c8+c9+c10+c11+c12+c13+c14)/soru1,"kg CO2.")
# Out:
# Evde kaç kişi yaşıyor?  4
# Yıllık kaç kwH elektrik kullanıyorsunuz?  10000
# Elektrik kaynaklı karbon ayak iziniz 336.6 kg CO2
# Yıllık kaç m3 doğalgaz kullanıyorsunuz?  10000
# Doğalgaz kaynaklı karbon ayak iziniz 21857.000000000004 kg CO2
# Odun kullanıyor musunuz? (evet/hayır)  hayır
# Kömür kullanıyor musunuz? (evet/hayır)  hayır
# Yakacak kaynaklı karbon ayak iziniz 0.0 kg CO2.
# Araba kullanıyor musunuz?(evet/hayır)  evet
# Arabanız hangi yakıtla çalışmaktadır? (benzin/dizel/lpg)  dizel
# Yılda kaç litre yakıt kullanıyorsunuz?  300
# Toplu taşıma kullanıyor musunuz? (evet/hayır)  evet
# Yılda kaç km yol kat ediyorsunuz?  2000
# Yılda kaç uçak yolcuğu yapıyorsunuz? (yapmıyorsanız 0 yazılabir)  0
# Yaptığınız yolculuk kaç saat sürüyor? (tek yön)  1
# Ulaşım ve seyahat kaynaklı karbon ayak iziniz 14130.0 kg CO2.
# yılda kaç kg kırmızı et tüketiyorsunuz?  40
# yılda kaç kg beyaz et tüketiyorsunuz?  50
# yılda kaç kg sebze tüketiyorsunuz?  100
# ...
